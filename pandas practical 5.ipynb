# %% [markdown]
# #How to write csv file:part2

# %%
import pandas as pd

# %%
pd.read_csv('D:\Movies\BOLLYWOOD\Flames\Book2.csv')
# Out:
#   Student_id  class  sleep_hr  math  science  marathi  hindi  total
# 0      S0001      7         6    60       90       78     56     67
# 1      S0002      5         4    90       60       67     78     76
# 2      S0003      6         6    70       70       56     98     56
# 3      S0004      9         8    50       80       34     43     89
# 4      S0005      3         5    50       80       89     53     76
# 5      S0006      6         5    60       80       76     63     49
# 6      S0007      2         5    60       89       56     73     78

# %%
pd.read_csv('D:\Movies\BOLLYWOOD\Flames\Book2.csv')
# Out:
#             0      1         2     3        4        5      6      7
# 0  Student_id  class  sleep_hr  math  science  marathi  hindi  total
# 1       S0001      7         6    60       90       78     56     67
# 2       S0002      5         4    90       60       67     78     76
# 3       S0003      6         6    70       70       56     98     56
# 4       S0004      9         8    50       80       34     43     89
# 5       S0005      3         5    50       80       89     53     76
# 6       S0006      6         5    60       80       76     63     49
# 7       S0007      2         5    60       89       56     73     78

# %% [markdown]
# #We dont want header that type we need header student_id.......

# %%
pd.read_csv('D:\Movies\BOLLYWOOD\Flames\Book2.csv',header=1)
# Out:
#   Student_id  class  sleep_hr  math  science  marathi  hindi  total
# 0      S0001      7         6    60       90       78     56     67
# 1      S0002      5         4    90       60       67     78     76
# 2      S0003      6         6    70       70       56     98     56
# 3      S0004      9         8    50       80       34     43     89
# 4      S0005      3         5    50       80       89     53     76
# 5      S0006      6         5    60       80       76     63     49
# 6      S0007      2         5    60       89       56     73     78

# %%
pd.read_csv('D:\Movies\BOLLYWOOD\Flames\Book2.csv')
# Out:
#    Unnamed: 0 Unnamed: 1      Data Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  Student_id      class  sleep_hr       math    science    marathi
# 1       S0001          7         6         60         90         78
# 2       S0002          5         4         90         60         67
# 3       S0003          6         6         70         70         56
# 4       S0004          9         8         50         80         34
# 5       S0005          3         5         50         80         89
# 6       S0006          6         5         60         80         76
# 7       S0007          2         5         60         89         56
#
#   Unnamed: 6 Unnamed: 7
# 0      hindi      total
# 1         56         67
# 2         78         76
# 3         98         56
# 4         43         89
# 5         53         76
# 6         63         49
# 7         73         78

# %% [markdown]
# #If we dont want headre then...

# %%
pd.read_csv('D:\Movies\BOLLYWOOD\Flames\Book2.csv',header=None)
# Out:
#             0      1         2     3        4        5      6      7
# 0         NaN    NaN      Data   NaN      NaN      NaN    NaN    NaN
# 1  Student_id  class  sleep_hr  math  science  marathi  hindi  total
# 2       S0001      7         6    60       90       78     56     67
# 3       S0002      5         4    90       60       67     78     76
# 4       S0003      6         6    70       70       56     98     56
# 5       S0004      9         8    50       80       34     43     89
# 6       S0005      3         5    50       80       89     53     76
# 7       S0006      6         5    60       80       76     63     49
# 8       S0007      2         5    60       89       56     73     78

# %%
pd.read_csv('D:\Movies\BOLLYWOOD\Flames\Book2.csv',header=1)
# Out:
#   Student_id  class  sleep_hr  math  science  marathi  hindi  total
# 0      S0001      7         6    60       90       78     56     67
# 1      S0002      5         4    90       60       67     78     76
# 2      S0003      6         6    70       70       56     98     56
# 3      S0004      9         8    50       80       34     43     89
# 4      S0005      3         5    50       80       89     53     76
# 5      S0006      6         5    60       80       76     63     49
# 6      S0007      2         5    60       89       56     73     78

# %% [markdown]
# #headre and prefix

# %%
pd.read_csv('D:\Movies\BOLLYWOOD\Flames\Book2.csv')
# Out:
#    S0001  7  6  60  90  78  56  67
# 0  S0002  5  4  90  60  67  78  76
# 1  S0003  6  6  70  70  56  98  56
# 2  S0004  9  8  50  80  34  43  89
# 3  S0005  3  5  50  80  89  53  76
# 4  S0006  6  5  60  80  76  63  49
# 5  S0007  2  5  60  89  56  73  78

# %%
pd.read_csv('D:\Movies\BOLLYWOOD\Flames\Book2.csv',header=None)
# Out:
#        0  1  2   3   4   5   6   7
# 0  S0001  7  6  60  90  78  56  67
# 1  S0002  5  4  90  60  67  78  76
# 2  S0003  6  6  70  70  56  98  56
# 3  S0004  9  8  50  80  34  43  89
# 4  S0005  3  5  50  80  89  53  76
# 5  S0006  6  5  60  80  76  63  49
# 6  S0007  2  5  60  89  56  73  78

# %%
pd.read_csv('D:\Movies\BOLLYWOOD\Flames\Book2.csv',header=None , prefix ="columns")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 pd.read_csv('D:\Movies\BOLLYWOOD\Flames\Book2.csv',header=None , prefix ="columns")
#
# TypeError: read_csv() got an unexpected keyword argument 'prefix'

# %% [markdown]
# #To give name to each column

# %%
pd.read_csv('D:\Movies\BOLLYWOOD\Flames\Book2.csv')
# Out:
#    S0001  7  6  60  90  78  56  67
# 0  S0002  5  4  90  60  67  78  76
# 1  S0003  6  6  70  70  56  98  56
# 2  S0004  9  8  50  80  34  43  89
# 3  S0005  3  5  50  80  89  53  76
# 4  S0006  6  5  60  80  76  63  49
# 5  S0007  2  5  60  89  56  73  78

# %%
pd.read_csv('D:\Movies\BOLLYWOOD\Flames\Book2.csv',names=['A','B','C','D','E','F','G','H'])
# Out:
#        A  B  C   D   E   F   G   H
# 0  S0001  7  6  60  90  78  56  67
# 1  S0002  5  4  90  60  67  78  76
# 2  S0003  6  6  70  70  56  98  56
# 3  S0004  9  8  50  80  34  43  89
# 4  S0005  3  5  50  80  89  53  76
# 5  S0006  6  5  60  80  76  63  49
# 6  S0007  2  5  60  89  56  73  78
