# %% [markdown]
# #interpolate()..

# %%
import pandas as pd

# %%
df=pd.read_csv('D:\Movies\BOLLYWOOD\Flames\Book6.csv')
df
# Out:
#          date  student_id  class section  study hr
# 0  01-07-2023       101.0      4       A       2.0
# 1  02-07-2023       102.0      5       B       3.0
# 2  03-07-2023         NaN      6     NaN       NaN
# 3  04-07-2023         NaN      7       C       NaN
# 4  05-07-2023       105.0      8     NaN       6.0

# %%
df.interpolate()
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_10024\4002874584.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate()
#          date  student_id  class section  study hr
# 0  01-07-2023       101.0      4       A       2.0
# 1  02-07-2023       102.0      5       B       3.0
# 2  03-07-2023       103.0      6     NaN       4.0
# 3  04-07-2023       104.0      7       C       5.0
# 4  05-07-2023       105.0      8     NaN       6.0

# %%
df.interpolate(method='linear')
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_10024\1321276365.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='linear')
#          date  student_id  class section  study hr
# 0  01-07-2023       101.0      4       A       2.0
# 1  02-07-2023       102.0      5       B       3.0
# 2  03-07-2023       103.0      6     NaN       4.0
# 3  04-07-2023       104.0      7       C       5.0
# 4  05-07-2023       105.0      8     NaN       6.0

# %%
df.interpolate(method='time')
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_10024\722817345.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='time')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df.interpolate(method='time')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:8206, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    8204 else:
#    8205     index = missing.get_interp_index(method, obj.index)
# -> 8206     new_data = obj._mgr.interpolate(
#    8207         method=method,
#    8208         index=index,
#    8209         limit=limit,
#    8210         limit_direction=limit_direction,
#    8211         limit_area=limit_area,
# ...

# %%
type(df.date[0])
# Out:
# str

# %%
df=pd.read_csv('D:\Movies\BOLLYWOOD\Flames\Book6.csv',parse_dates=['date'])
df
# Out:
#         date  student_id  class section  study hr
# 0 2023-01-07       101.0      4       A       2.0
# 1 2023-02-07       102.0      5       B       3.0
# 2 2023-03-07         NaN      6     NaN       NaN
# 3 2023-04-07         NaN      7       C       NaN
# 4 2023-05-07       105.0      8     NaN       6.0

# %%
df=pd.read_csv('D:\Movies\BOLLYWOOD\Flames\Book6.csv',parse_dates=['date'],index_col='date')
df
# Out:
#             student_id  class section  study hr
# date
# 2023-01-07       101.0      4       A       2.0
# 2023-02-07       102.0      5       B       3.0
# 2023-03-07         NaN      6     NaN       NaN
# 2023-04-07         NaN      7       C       NaN
# 2023-05-07       105.0      8     NaN       6.0

# %%
df.interpolate(method='time')
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_10024\722817345.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='time')
#             student_id  class section  study hr
# date
# 2023-01-07  101.000000      4       A  2.000000
# 2023-02-07  102.000000      5       B  3.000000
# 2023-03-07  102.943820      6     NaN  3.943820
# 2023-04-07  103.988764      7       C  4.988764
# 2023-05-07  105.000000      8     NaN  6.000000

# %%
df.interpolate(method='index')
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_10024\2515484856.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='index')
#             student_id  class section  study hr
# date
# 2023-01-07  101.000000      4       A  2.000000
# 2023-02-07  102.000000      5       B  3.000000
# 2023-03-07  102.943820      6     NaN  3.943820
# 2023-04-07  103.988764      7       C  4.988764
# 2023-05-07  105.000000      8     NaN  6.000000

# %%
df=pd.read_csv('D:\Movies\BOLLYWOOD\Flames\Book6.csv',parse_dates=['date'],index_col='date')
df
# Out:
#             student_id  class section  study hr
# date
# 2023-01-07       101.0      4       A       2.0
# 2023-02-07       102.0      5       B       3.0
# 2023-03-07         NaN      6     NaN       NaN
# 2023-04-07         NaN      7       C       NaN
# 2023-05-07       105.0      8     NaN       6.0

# %%
df.interpolate(method='index')
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_10024\2515484856.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='index')
#             student_id  class section  study hr
# date
# 2023-01-07  101.000000      4       A  2.000000
# 2023-02-07  102.000000      5       B  3.000000
# 2023-03-07  102.943820      6     NaN  3.943820
# 2023-04-07  103.988764      7       C  4.988764
# 2023-05-07  105.000000      8     NaN  6.000000

# %%
df.interpolate(method='nearest')
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_10024\1654062127.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='nearest')
#             student_id  class section  study hr
# date
# 2023-01-07       101.0      4       A       2.0
# 2023-02-07       102.0      5       B       3.0
# 2023-03-07       102.0      6     NaN       3.0
# 2023-04-07       105.0      7       C       6.0
# 2023-05-07       105.0      8     NaN       6.0

# %%
df.interpolate(method='polynomial',order=1)
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_10024\587008278.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='polynomial',order=1)
#             student_id  class section  study hr
# date
# 2023-01-07  101.000000      4       A  2.000000
# 2023-02-07  102.000000      5       B  3.000000
# 2023-03-07  102.943820      6     NaN  3.943820
# 2023-04-07  103.988764      7       C  4.988764
# 2023-05-07  105.000000      8     NaN  6.000000

# %%
df.interpolate(method='polynomial',order=2)
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_10024\2432539652.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='polynomial',order=2)
#             student_id  class section  study hr
# date
# 2023-01-07  101.000000      4       A  2.000000
# 2023-02-07  102.000000      5       B  3.000000
# 2023-03-07  102.923185      6     NaN  3.923185
# 2023-04-07  103.967379      7       C  4.967379
# 2023-05-07  105.000000      8     NaN  6.000000

# %%
df.interpolate(method='spline',order=2)  #rectangular key fillinf
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_10024\79068096.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='spline',order=2)  #rectangular key fillinf
#             student_id  class section  study hr
# date
# 2023-01-07  101.000000      4       A  2.000000
# 2023-02-07  102.000000      5       B  3.000000
# 2023-03-07  102.923185      6     NaN  3.923185
# 2023-04-07  103.967379      7       C  4.967379
# 2023-05-07  105.000000      8     NaN  6.000000
