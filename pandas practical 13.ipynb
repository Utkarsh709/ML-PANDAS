# %% [markdown]
# #interpolate()..part2

# %%
import pandas as pd

# %%
df=pd.read_csv('D:\Movies\BOLLYWOOD\Flames\Book6.csv')
df
# Out:
#          date  student_id  class  study hr
# 0  01-07-2023       101.0      4       2.0
# 1  02-07-2023       102.0      5       3.0
# 2  03-07-2023         NaN      6       NaN
# 3  04-07-2023         NaN      7       NaN
# 4  05-07-2023       105.0      8       6.0

# %%
df.interpolate()
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_2548\4002874584.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate()
#          date  student_id  class  study hr
# 0  01-07-2023       101.0      4       2.0
# 1  02-07-2023       102.0      5       3.0
# 2  03-07-2023       103.0      6       4.0
# 3  04-07-2023       104.0      7       5.0
# 4  05-07-2023       105.0      8       6.0

# %%
df.dtypes
# Out:
# date           object
# student_id    float64
# class           int64
# study hr      float64
# dtype: object

# %%
df.interpolate(limit=1)
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_2548\1270544217.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(limit=1)
#          date  student_id  class  study hr
# 0  01-07-2023       101.0      4       2.0
# 1  02-07-2023       102.0      5       3.0
# 2  03-07-2023       103.0      6       4.0
# 3  04-07-2023         NaN      7       NaN
# 4  05-07-2023       105.0      8       6.0

# %%
df.interpolate(limit=1,limit_direction='backward') #takes by default forward
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_2548\3443271525.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(limit=1,limit_direction='backward') #takes by default forward
#          date  student_id  class  study hr
# 0  01-07-2023       101.0      4       2.0
# 1  02-07-2023       102.0      5       3.0
# 2  03-07-2023         NaN      6       NaN
# 3  04-07-2023       104.0      7       5.0
# 4  05-07-2023       105.0      8       6.0

# %%
df.interpolate(limit=1,limit_direction='both') #takes by default forward
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_2548\3211511187.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(limit=1,limit_direction='both') #takes by default forward
#          date  student_id  class  study hr
# 0  01-07-2023       101.0      4       2.0
# 1  02-07-2023       102.0      5       3.0
# 2  03-07-2023       103.0      6       4.0
# 3  04-07-2023       104.0      7       5.0
# 4  05-07-2023       105.0      8       6.0

# %%
df.interpolate(limit_area='inside')
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_2548\2930091247.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(limit_area='inside')
#          date  student_id  class  study hr
# 0  01-07-2023       101.0      4       2.0
# 1  02-07-2023       102.0      5       3.0
# 2  03-07-2023       103.0      6       4.0
# 3  04-07-2023       104.0      7       5.0
# 4  05-07-2023       105.0      8       6.0

# %%
df.interpolate(limit_area='outside')
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_2548\1653127404.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(limit_area='outside')
#          date  student_id  class  study hr
# 0  01-07-2023       101.0      4       2.0
# 1  02-07-2023       102.0      5       3.0
# 2  03-07-2023         NaN      6       NaN
# 3  04-07-2023         NaN      7       NaN
# 4  05-07-2023       105.0      8       6.0

# %%
df.interpolate(inplace=True)#we have to value parameter with it but bydefault interpolate filled the missing value by method='linear'
df
# Out:
# C:\Users\AS\AppData\Local\Temp\ipykernel_2548\2001019460.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(inplace=True)#we have to value parameter with it but bydefault interpolate filled the missing value by method='linear'
#          date  student_id  class  study hr
# 0  01-07-2023       101.0      4       2.0
# 1  02-07-2023       102.0      5       3.0
# 2  03-07-2023       103.0      6       4.0
# 3  04-07-2023       104.0      7       5.0
# 4  05-07-2023       105.0      8       6.0

# %%
df
# Out:
#          date  student_id  class  study hr
# 0  01-07-2023       101.0      4       2.0
# 1  02-07-2023       102.0      5       3.0
# 2  03-07-2023       103.0      6       4.0
# 3  04-07-2023       104.0      7       5.0
# 4  05-07-2023       105.0      8       6.0
