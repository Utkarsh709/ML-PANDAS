# %%
import pandas as pd

# %% [markdown]
# #isnull()...count total null values in dataframe

# %%
df=pd.read_csv('D:\Movies\BOLLYWOOD\Flames\practice.csv')
df
# Out:
#    A   B    C  D    E
# 0  1  12  9.0  4  2.0
# 1  2  23  8.0  3  3.0
# 2  3  34  NaN  2  4.0
# 3  4  45  NaN  1  NaN
# 4  5  56  5.0  0  NaN

# %%
df.isnull()
# Out:
#        A      B      C      D      E
# 0  False  False  False  False  False
# 1  False  False  False  False  False
# 2  False  False   True  False  False
# 3  False  False   True  False   True
# 4  False  False  False  False   True

# %%
df.isnull().sum()
# Out:
# A    0
# B    0
# C    2
# D    0
# E    2
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 4

# %%
df.notnull()
# Out:
#       A     B      C     D      E
# 0  True  True   True  True   True
# 1  True  True   True  True   True
# 2  True  True  False  True   True
# 3  True  True  False  True  False
# 4  True  True   True  True  False

# %%
df.notnull().sum()
# Out:
# A    5
# B    5
# C    3
# D    5
# E    3
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# 21

# %% [markdown]
# #for series()....

# %%
import numpy as np
sr=pd.Series([3,4,5,np.nan,8,9,np.NaN])
sr
# Out:
# 0    3.0
# 1    4.0
# 2    5.0
# 3    NaN
# 4    8.0
# 5    9.0
# 6    NaN
# dtype: float64

# %%
sr.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
sr.isnull().sum()
# Out:
# 2

# %%
sr.isnull().sum().sum()
# Out:
# 2

# %%
sr.notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# 6    False
# dtype: bool

# %%
sr.notnull().sum()
# Out:
# 5
